# %%
from decomposition import multiply, svd_decompose

A = [[-1.0, 3.0], [-2.0, 4.0]]

U, Sigma, VT = svd_decompose(A)

print(U, Sigma, VT, sep="\n")

print(multiply(U, multiply(Sigma, VT)))
# Out:
# [[0.5760484367663208, 0.8174155604703632], [0.8174155604703632, -0.5760484367663211]]
# [[5.464985704219043, 0.0], [0.0, 0.3659661906262559]]
# [[-0.4045535848337569, 0.9145142956773045], [0.9145142956773045, 0.4045535848337569]]
# [[-1.0000000000000016, 2.9999999999999996], [-1.9999999999999991, 4.0]]
